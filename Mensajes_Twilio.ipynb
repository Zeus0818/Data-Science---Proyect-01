# %% [markdown]
# <a href="https://colab.research.google.com/github/Zeus0818/Data-Science---Proyect-01/blob/main/Mensajes_Twilio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install twilio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.2 MB/s eta 0:00:00
# ...

# %%
import os
from twilio.rest import Client
from twilio_config import *
import time

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json


import pandas as pd
import requests
from bs4  import BeautifulSoup
from tqdm import tqdm

from datetime import datetime

# %% [markdown]
# # Armado de la URL

# %%
query = 'Lima'
api_key = API_KEY_WAPI

url_clima = 'http://api.weatherapi.com/v1/forecast.json?key='+api_key+'&q='+query+ '&days=1&aqi=no&alerts=no'
url_clima
# Out:
# 'http://api.weatherapi.com/v1/forecast.json?key=f3cf65ff7ae64bccad9210657220807&q=Lima&days=1&aqi=no&alerts=no'

# %%
response = requests.get(url_clima).json()

# %%
response
# Out:
# {'location': {'name': 'Lima',
#   'region': 'Lima',
#   'country': 'Peru',
#   'lat': -12.05,
#   'lon': -77.05,
#   'tz_id': 'America/Lima',
#   'localtime_epoch': 1724432940,
#   'localtime': '2024-08-23 12:09'},
#  'current': {'last_updated_epoch': 1724432400,
#   'last_updated': '2024-08-23 12:00',
#   'temp_c': 16.7,
#   'temp_f': 62.0,
#   'is_day': 1,
#   'condition': {'text': 'Patchy rain nearby',
#    'icon': '//cdn.weatherapi.com/weather/64x64/day/176.png',
#    'code': 1063},
#   'wind_mph': 7.6,
#   'wind_kph': 12.2,
#   'wind_degree': 233,
#   'wind_dir': 'SW',
#   'pressure_mb': 1016.0,
#   'pressure_in': 30.0,
#   'precip_mm': 0.01,
#   'precip_in': 0.0,
#   'humidity': 79,
#   'cloud': 62,
#   'feelslike_c': 16.7,
#   'feelslike_f': 62.0,
#   'windchill_c': 16.7,
#   'windchill_f': 62.0,
#   'heatindex_c': 16.7,
#   'heatindex_f': 62.0,
#   'dewpoint_c': 13.1,
#   'dewpoint_f': 55.6,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 5.0,
#   'gust_mph': 8.7,
# ...

# %%
response.keys()
# Out:
# dict_keys(['location', 'current', 'forecast'])

# %%
response['forecast']['forecastday'][0].keys()
# Out:
# dict_keys(['date', 'date_epoch', 'day', 'astro', 'hour'])

# %%
len(response['forecast']['forecastday'][0]['hour'])
# Out:
# 24

# %%
response['forecast']['forecastday'][0]['hour'][0]
# Out:
# {'time_epoch': 1724389200,
#  'time': '2024-08-23 00:00',
#  'temp_c': 14.4,
#  'temp_f': 57.8,
#  'is_day': 0,
#  'condition': {'text': 'Patchy rain nearby',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#   'code': 1063},
#  'wind_mph': 4.5,
#  'wind_kph': 7.2,
#  'wind_degree': 194,
#  'wind_dir': 'SSW',
#  'pressure_mb': 1015.0,
#  'pressure_in': 29.97,
#  'precip_mm': 0.02,
#  'precip_in': 0.0,
#  'snow_cm': 0.0,
#  'humidity': 86,
#  'cloud': 62,
#  'feelslike_c': 14.3,
#  'feelslike_f': 57.7,
#  'windchill_c': 14.3,
#  'windchill_f': 57.7,
#  'heatindex_c': 14.4,
#  'heatindex_f': 57.8,
#  'dewpoint_c': 12.0,
#  'dewpoint_f': 53.7,
#  'will_it_rain': 1,
#  'chance_of_rain': 74,
#  'will_it_snow': 0,
#  'chance_of_snow': 0,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'gust_mph': 6.7,
#  'gust_kph': 10.8,
#  'uv': 0}

# %%
response['forecast']['forecastday'][0]['hour'][0]['time'].split()[0]  #fecha
# Out:
# '2024-08-23'

# %%
response['forecast']['forecastday'][0]['hour'][1]['time'].split()[1] #hora [1] = '01:00'
# Out:
# '01:00'

# %%
int(response['forecast']['forecastday'][0]['hour'][1]['time'].split()[1].split(':')[0])  #hora [1] = '01:00'
# Out:
# 1

# %%
response['forecast']['forecastday'][0]['hour'][0] # Condicion
# Out:
# {'time_epoch': 1724389200,
#  'time': '2024-08-23 00:00',
#  'temp_c': 14.4,
#  'temp_f': 57.8,
#  'is_day': 0,
#  'condition': {'text': 'Patchy rain nearby',
#   'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#   'code': 1063},
#  'wind_mph': 4.5,
#  'wind_kph': 7.2,
#  'wind_degree': 194,
#  'wind_dir': 'SSW',
#  'pressure_mb': 1015.0,
#  'pressure_in': 29.97,
#  'precip_mm': 0.02,
#  'precip_in': 0.0,
#  'snow_cm': 0.0,
#  'humidity': 86,
#  'cloud': 62,
#  'feelslike_c': 14.3,
#  'feelslike_f': 57.7,
#  'windchill_c': 14.3,
#  'windchill_f': 57.7,
#  'heatindex_c': 14.4,
#  'heatindex_f': 57.8,
#  'dewpoint_c': 12.0,
#  'dewpoint_f': 53.7,
#  'will_it_rain': 1,
#  'chance_of_rain': 74,
#  'will_it_snow': 0,
#  'chance_of_snow': 0,
#  'vis_km': 10.0,
#  'vis_miles': 6.0,
#  'gust_mph': 6.7,
#  'gust_kph': 10.8,
#  'uv': 0}

# %% [markdown]
# # Dataframe

# %%
def get_forecast(response,i): #respuesta del API , iterador

    fecha = response['forecast']['forecastday'][0]['hour'][i]['time'].split()[0]
    hora = int(response['forecast']['forecastday'][0]['hour'][i]['time'].split()[1].split(':')[0])
    condicion = response['forecast']['forecastday'][0]['hour'][i]['condition']['text']
    tempe = float(response['forecast']['forecastday'][0]['hour'][i]['temp_c'])
    rain = response['forecast']['forecastday'][0]['hour'][i]['will_it_rain']
    prob_rain = response['forecast']['forecastday'][0]['hour'][i]['chance_of_rain']

    return fecha,hora,condicion,tempe,rain,prob_rain

# %%
datos = []

for i in tqdm(range(len(response['forecast']['forecastday'][0]['hour'])),colour = 'green'):

    datos.append(get_forecast(response,i))
# Out:
# 100%|██████████| 24/24 [00:00<00:00, 96978.13it/s]

# %%
datos[0]
# Out:
# ('2024-08-23', 0, 'Patchy rain nearby', 14.4, 1, 74)

# %%
#Convertimos el JSON a DATAFRAME
col = ['Fecha','Hora','Condicion','Temperatura','Lluvia','prob_lluvia']
df = pd.DataFrame(datos,columns=col)
df = df.sort_values(by = 'Hora',ascending = True)
df
# Out:
#          Fecha  Hora           Condicion  Temperatura  Lluvia  prob_lluvia
# 0   2024-08-23     0  Patchy rain nearby         14.4       1           74
# 1   2024-08-23     1  Patchy rain nearby         14.4       0           64
# 2   2024-08-23     2  Patchy rain nearby         14.1       1           87
# 3   2024-08-23     3  Patchy rain nearby         14.1       0           64
# 4   2024-08-23     4  Patchy rain nearby         14.1       1           75
# 5   2024-08-23     5  Patchy rain nearby         14.1       1           88
# 6   2024-08-23     6  Patchy rain nearby         14.1       1           89
# 7   2024-08-23     7  Patchy rain nearby         14.3       0           60
# 8   2024-08-23     8             Cloudy          15.5       0            0
# 9   2024-08-23     9             Cloudy          15.9       0            0
# 10  2024-08-23    10  Patchy rain nearby         16.3       1           85
# ...

# %%
# data_cli = {
#     'Fecha':datos[0][0],
#     'Hora':datos[1][],
#     'Tiempo':condicion,
#     'Temperatura':tempe,
#     'LLoverá':rain,
#     'prob_lluvia':prob_rain

# }

# df = pd.DataFrame(data_cli)
# df = df.sort_values(by = 'Hora',ascending = True)

# %%
df[df['Lluvia']==1]
# Out:
#          Fecha  Hora           Condicion  Temperatura  Lluvia  prob_lluvia
# 0   2024-08-23     0  Patchy rain nearby         14.4       1           74
# 2   2024-08-23     2  Patchy rain nearby         14.1       1           87
# 4   2024-08-23     4  Patchy rain nearby         14.1       1           75
# 5   2024-08-23     5  Patchy rain nearby         14.1       1           88
# 6   2024-08-23     6  Patchy rain nearby         14.1       1           89
# 10  2024-08-23    10  Patchy rain nearby         16.3       1           85
# 11  2024-08-23    11  Patchy rain nearby         16.6       1           72
# 12  2024-08-23    12  Patchy rain nearby         16.7       1           80
# 23  2024-08-23    23  Patchy rain nearby         14.2       1           75

# %%
df_rain =  df[(df['Lluvia']==1) & (df['Hora']>6) & (df['Hora']< 22)]
df_rain = df_rain[['Hora','Condicion']]
df_rain.set_index('Hora', inplace = True)

# %%
df['Fecha'][0]
# Out:
# '2024-08-23'

# %%
df_rain
# Out:
#                Condicion
# Hora
# 10    Patchy rain nearby
# 11    Patchy rain nearby
# 12    Patchy rain nearby

# %%
'\nHola! \n\n\n El pronostico del tiempo hoy '+ df['Fecha'][0] +' en ' + query +' es : \n\n\n ' + str(df_rain)
# Out:
# '\nHola! \n\n\n El pronostico del tiempo hoy 2024-08-23 en Lima es : \n\n\n                Condicion\nHora                    \n10    Patchy rain nearby\n11    Patchy rain nearby\n12    Patchy rain nearby'

# %%
PHONE_NUMBER
# Out:
# '+19546136053'

# %% [markdown]
# # Mensaje SMS desde Twilio

# %%
time.sleep(2)
account_sid = TWILIO_ACCOUNT_SID
auth_token = TWILIO_AUTH_TOKEN

client = Client(account_sid, auth_token)

message = client.messages \
                .create(
                     body='\nHola! \n\n\n El pronostico de lluvia hoy '+ df['Fecha'][0] +' en ' + query +' es : \n\n\n ' + str(df_rain),
                     from_=PHONE_NUMBER,
                     to='+51915245526'
                 )

print('Mensaje Enviado ' + message.sid)
# Out:
# Mensaje Enviado SM78519beae8d5a41f5b7472fcfcfab553

# %% [markdown]
# # Challenge
#
# * Extrae el valor del dolar en tu país y el top 10 de criptomonedas con su respectiva valoración
# * Ahora envia un mensaje diarío a tu Whatsapp usando Twilio
#
# **hint 💡** Investiga que API's gratuitas existen para consultar estos datos
#
#
#
# <img src="WhatsApp Image 2022-09-13 at 9.12.18 AM.jpeg" width="200" height="200" />
